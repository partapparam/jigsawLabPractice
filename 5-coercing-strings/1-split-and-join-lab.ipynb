# %% [markdown]
# # Split and Join Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, we'll practice working with `split` and `join`.  We'll do so to practice working with some location information from [Texas Drink Receipts API](https://data.texas.gov/Government-and-Taxes/Mixed-Beverage-Gross-Receipts/naix-2893).

# %% [markdown]
# ### Loading our data

# %% [markdown]
# To begin with, let's get a bunch of store locations for Max's Wine Bar.

# %%
import pandas as pd
df = pd.read_json("https://raw.githubusercontent.com/eng-6-22/mod-1-a-data-structures/master/5-coercing-strings/locations.json")

# %%
locations = list(df.location_address)
locations[0:3]
# Out:
# ['2914 HARRY HINES BLVD', '3001 PABLO KISEL BLVD STE N', '21815 W HWY 71']

# %% [markdown]
# Now let's say that we need to separate the street number from the rest of the street address for each element.  So this way we can can have a list of just the streets of the locations.

# %% [markdown]
# ```python
# ['HARRY HINES BLVD', 'PABLO KISEL BLVD STE N', 'W HWY 71']
# ```

# %% [markdown]
# 1. Do it for one element.

# %% [markdown]
# Let's start by accomplishing this for a single string, so that we turn an address like `'2914 HARRY HINES BLVD'` into `'HARRY HINES BLVD'`.

# %% [markdown]
# > Press shift + return on the cell below.

# %%
address = '2914 HARRY HINES BLVD'

# %% [markdown]
# > To start, let's take our address above and turn the string into a list of words.

# %%
address_words = address.split(' ')
address_words
# ['2914', 'HARRY', 'HINES', 'BLVD']
# Out:
# ['2914', 'HARRY', 'HINES', 'BLVD']

# %% [markdown]
# > Then select every element after the first element, and turn them back into a string.

# %%
address_street_words = ' '.join(address_words[1:])
address_street_words
# 'HARRY HINES BLVD'
# Out:
# 'HARRY HINES BLVD'

# %% [markdown]
# 2. Do it for all

# %% [markdown]
# Now that we determined how to do this for one of the reviews, let's form a list of all of the streets.

# %%
address_streets = []
for address in locations:
  words = address.split(' ')
  address_streets.append(' '.join(words[1:]))
address_streets
# Out:
# ['HARRY HINES BLVD',
#  'PABLO KISEL BLVD STE N',
#  'W HWY 71',
#  'SLIDE RD STE 100',
#  'WATERWAY AVE SUITE 110R-A',
#  'STUDEMONT ST STE 900',
#  'ANTHEM DR',
#  'S HIGHWAY 146',
#  'SCHATZEL ST',
#  'W COTTER AVE',
#  'EAST FREEWAY 83',
#  'CAMP ST',
#  'S TREADAWAY BLVD',
#  'N US HIGHWAY 35 BYP',
#  '50TH ST',
#  'E 5TH ST',
#  'W 7TH ST',
#  'MONTFORT DR',
#  'S COCKRELL HILL RD STE 100',
#  'KEMAH WATERFRONT ST',
#  'INTERSTATE 45 N',
#  'W 30TH ST',
#  'BRUTON RD',
#  'E SE LOOP 323',
#  'W 11TH ST',
#  'VETERANS BLVD STE F',
#  'N TRAVIS ST',
#  'HIGHWAY 71 W STE 180',
#  'ELM ST',
#  'S MAIN ST',
#  'WEST RD',
#  'E MAIN ST',
#  'S CONGRESS AVE',
#  'INDUSTRIAL RD',
#  'LOOP 250 W',
#  'DALLAS ST STE P50',
#  'NW MILITARY HWY',
#  'STATE HIGHWAY 205',
#  'N VALLEY MILLS DR',
#  'STEWART RD',
#  'POST OAK BLVD STE 1E',
#  'LAKESHORE DR',
#  'S STEMMONS FWY',
#  'TECHNOLOGY BLVD W',
#  'FOSSIL BLUFF DR',
#  'E PIONEER PKWY',
#  'W GRAY ST',
#  'SAINT EMANUEL ST',
#  'COUNTRY CREEK DR',
#  'E 6TH ST STE A',
#  'IH 10 W',
#  'COLLEYVILLE BLVD',
#  'COUNTRY CLUB DRIVE',
#  'MCKINNEY AVE STE 107',
#  'NORTH FWY STE 120',
#  'SW MILITARY DR',
#  'W 6TH ST',
#  'ANTHONY ST',
#  'KATY FWY STE A',
#  'W HWY 287 (ENNIS AVENUE)',
#  'SE MILITARY DR',
#  'HARRIS AVE',
#  'N LOOP 1604 W STE 2101',
#  'E 42ND ST # F2',
#  'GARDEN PARK DR',
#  'CENTRAL EXPY',
#  'S BROADWAY AVE',
#  'ROARING SPRINGS RD',
#  'SAWDUST RD',
#  'HIGHWAY 80 W',
#  'W AMARILLO BLVD',
#  'CONLEY ST',
#  'E ABRAM ST # 110-114',
#  'W MAIN ST',
#  'N STEMMONS FWY',
#  'W 5TH ST',
#  'W 5TH ST',
#  'CONGRESS AVE STE C',
#  'HIGHWAY 6 S',
#  'W INTERSTATE 40',
#  'REGENT BLVD',
#  'MONTEGO DR',
#  'N NEW BRAUNFELS AVE',
#  'FM 1942 RD',
#  'TOWN SQUARE PL',
#  'WASHINGTON AVE STE C',
#  'W PARKER RD',
#  'E HIGHWAY 67',
#  'E SEALY ST',
#  'SW LOOP 410 STE 208',
#  'HIGHWAY 290 W',
#  'MAIN ST',
#  'RIO GRANDE ST',
#  'E RICHEY RD STE B',
#  'N CENTRAL EXPY',
#  'N CENTRAL EXPY STE 120',
#  'FM 1960 RD W',
#  'ALDINE WESTFIELD RD',
#  'FM 1398',
#  'W GRAND PKWY S STE 110',
#  'W HICKORY ST',
#  'CYPRESS CREEK PKWY STE 104E',
#  'STATE HIGHWAY 249 STE G',
#  'N HOME ST',
#  'US HIGHWAY 87 E',
#  'N HENDERSON AVE',
#  'HWY 148 SOUTH',
#  'RUSK ST',
#  'WASHINGTON BLVD STE B',
#  'LEOPARD ST',
#  'CLUB DR',
#  'N 11TH ST',
#  'WEST FRWY #100',
#  'W IRVING BLVD',
#  'TEXAS AVE',
#  'LAKE PARK RD',
#  'US HIGHWAY 281 N',
#  'MCCART AVE STE B',
#  'NORTHWEST FWY',
#  'US HIGHWAY 77',
#  'HOUSTON ST',
#  'E STASSNEY LN STE B',
#  'SE 10TH AVE',
#  'ROYAL LN STE 106',
#  'MOUNTAIN VALLEY DR',
#  'DE MOSS DR',
#  'WESTHEIMER RD',
#  'VISCOUNT BLVD STE J',
#  'S STEMMONS FWY STE A',
#  'N VALLEY VIEW RD',
#  'S HIGHWAY 377',
#  'OLD DENTON RD STE 700',
#  'MEMORIAL BLVD STE 100',
#  'HIGHWAY 87 N',
#  'AIRPORT BLVD',
#  'FANNIN ST',
#  'N BELT LINE RD STE A',
#  'CONTRARY CREEK RD STE 104-108',
#  'N BELT LINE RD STE A',
#  'PHARAOH DR',
#  'W SAM HOUSTON PKWY S',
#  'WONDER ST',
#  'E INTERSTATE 20 STE 100',
#  'KILGORE PLZ',
#  'COUNTRY CLUB LANE',
#  'E INTERSTATE 40',
#  'SUNSET BLVD STE A',
#  'AVENUE F STE F16',
#  'FOSTER FIELD DR',
#  'WET N WILD WAY',
#  'W HICKORY ST',
#  'TELEPHONE RD',
#  'S STEMMONS FWY',
#  'TEXAS AVE S',
#  'N CENTER ST',
#  'W LOOP 1604 N STE 110',
#  'TRULY PLZ',
#  'FM 311',
#  'WESTHEIMER RD',
#  'CENTRAL EXPY',
#  'S CENTRAL EXPY',
#  'WESTHEIMER PKWY STE C',
#  'CENTRAL EXPY S',
#  'BAY OAKS BLVD',
#  'E HOUSTON ST',
#  'MILLER RD',
#  'UNIVERSITY DR E',
#  'MAIN ST',
#  'RESEARCH BLVD STE 4000',
#  'COLE AVE STE 103',
#  'PAULS VALLEY RD STE G',
#  'GRAND AVE',
#  'N MESA ST # 309-311',
#  'FM 1960 RD E STE 163',
#  'S 17TH ST',
#  'N STATE HIGHWAY 95',
#  'STRICKLAND DR',
#  'KUYKENDAHL RD',
#  'E LAMAR BLVD',
#  'FOCH ST',
#  'HIGHWAY 290 STE A',
#  'ALMA ST STE A-B',
#  'E SAN ANTONIO AVE',
#  'W WASHINGTON ST',
#  'FORD CHAPEL RD',
#  'INTERSTATE 45 N',
#  'S SONCY RD',
#  'CINEMA RDG',
#  'E HOPKINS ST',
#  'MARTIN LUTHER KING JR BLVD',
#  'STATE ST',
#  'S TREADAWAY BLVD',
#  'E 7TH ST',
#  'W BAY AREA BLVD',
#  'TOWN EAST CROSSIG BLVD',
#  'N BEATON ST',
#  'AVENUE Q',
#  'BOCA CHICA BLVD STE B&C',
#  'E US HIGHWAY 80',
#  'S SAINT MARYS STE 100',
#  'W QUEEN ISABELLA',
#  'OLD DENTON RD STE 326',
#  'WEST FRWY #100',
#  'HIGHWAY 290',
#  'JOE RAMSEY BLVD E',
#  'S ALAMO ST',
#  'US 59 HWY',
#  'SW WILSHIRE BLVD STE K',
#  'BRADFORD AVE',
#  'REDWING DR',
#  'WILCREST',
#  'FM 1626 STE 370',
#  'HIGHWAY 59 N',
#  'ROYAL LN STE 106',
#  'FORT WORTH DR',
#  'W LAKE HOUSTON PKWY BLDG 9',
#  'CONGRESS AVE',
#  'WOODWAY DR',
#  'FM 1960 RD W',
#  'SUMMER LEE DR STE 107',
#  'INDUSTRIAL AVE',
#  'E CENTRAL AVE',
#  'NE LOOP 410',
#  'ALLEN ST',
#  'E ELDORADO PKWY',
#  'S VALLEY MILLS DRIVE',
#  'W MAIN ST',
#  'BAYWAY DR',
#  'OLD DENTON RD STE 598',
#  'MANOR RD',
#  'N BELT LINE RD STE 100',
#  'TOWN AND COUNTRY LN BLDG 10A STE 200',
#  'WESTHEIMER RD STE 1010',
#  'S SHARY RD',
#  'OAK LAWN AVE STE 101',
#  'HARRY WURZBACH RD',
#  'EDGE OF TEXAS',
#  'DICKINSON AVE',
#  'S JACKSON RD',
#  'W 5TH ST STE B',
#  'N INTERNATIONAL PKWY',
#  'HYATT RESORT DR',
#  'E 5TH ST',
#  'HIGHWAY 87',
#  'S GENERAL BRUCE DR',
#  'STATE HIGHWAY 6 S',
#  '1ST ST W',
#  'E AMARILLO BLVD',
#  'GULF FWY',
#  'DALLAS PKWY',
#  'S 8TH ST',
#  'AYERS ST',
#  'N MACARTHUR BLVD STE 150',
#  'ROYAL LN STE 102',
#  'INDUSTRIAL DR W',
#  'RIO GRANDE ST',
#  'E HOUSTON ST',
#  'PERRIN BEITEL RD',
#  'TOEPPERWEIN RD STE 101',
#  'E SOUTH 11TH ST',
#  'TOWNE CROSSING BLVD',
#  'ROYAL LN STE 101',
#  'HIGHWAY 6 N',
#  'E NORTHWEST HWY',
#  'S GESSNER DR',
#  'TOWNE CROSSING BLVD',
#  'W MOORE AVE',
#  'MIDWAY RD STE 101',
#  'INTERNATIONAL AIRPORT TERMINAL BLDG',
#  'N ED CAREY DR',
#  'BASSETT AVE',
#  'N STANTON ST INCLUDEDING 508 1/2',
#  'W 19TH ST',
#  'N GREENVILLE AVE STE 11B',
#  'ELM ST',
#  'COLORADO ST',
#  'OYSTER CREEK DR STE 10',
#  'PEDERNALES ST',
#  '22 HARBOR SIDE DR',
#  'E HIGHWAY 90A',
#  'SEA WORLD DR',
#  'FORT WORTH AVE',
#  'S HULEN ST',
#  'WICHITA AVE',
#  'HIGHWAY 6 N',
#  'EAST FWY',
#  'OCONNOR RD',
#  'E GRAND AVE',
#  'KILGORE PLZ',
#  'E UNIVERSITY BLVD',
#  'FM 1464 RD',
#  '8 N/S 1/2 MI W INT FM 988',
#  'CHASE OAKS BLVD',
#  'ROAD A1',
#  'N INTERSTATE 35 E',
#  'ROAD TO SIX FLAGS ST E STE 178',
#  'W GRAND PKWY S',
#  'W BAY AREA BLVD',
#  'HILL COUNTRY BLVD STE 100',
#  'W PARKER RD STE 109',
#  'ROSELAND ST',
#  'JOE FIELD RD',
#  'SPANGLER RD STE A',
#  'HUEBNER RD STE 208',
#  'EAGLE VISTA DR',
#  'STRICKLAND DR STE 110',
#  'KUYKENDAHL RD',
#  'E FM 544 STE 58',
#  'W GRAND PKWY S STE 110',
#  'UNIVERSITY DR',
#  'ANDERSON MILL RD # B-100',
#  'N EXPRESSWAY # 77',
#  'HOPE BLVD',
#  'W CROCKETTSTE 101',
#  'E 5TH ST',
#  'COLLEGE ST',
#  'LAKEVIEW PKWY',
#  'SIX PINES RD STE 100',
#  'COLE ST',
#  'DOMAIN DR STE 100',
#  'E 11TH ST',
#  'N LAMPASAS ST',
#  'FM 1434',
#  'SW LOOP 820',
#  'WESTERN CENTER BLVD',
#  'KUYKENDAHL RD',
#  'MLK BLVD',
#  'WOODFOREST BLVD STE P',
#  'ARLINGTON HIGHLANDS BLVD STE 137',
#  'OAK LAWN AVE',
#  'NACOGDOCHES RD',
#  'ASHLAND BLVD',
#  'CHESTNUT ST STE D',
#  'SAGE MEADOW TRL',
#  'SUNLAND PARK DR',
#  'UNIVERSITY AVE STE A',
#  'MAPLE AVE',
#  'BARTON CLUB DR',
#  'ROWLETT RD',
#  'PECAN',
#  'W MILLER RD',
#  'PECAN ST',
#  'N TEXAS BLVD',
#  'E AVENUE A',
#  'S MIRICK AVE',
#  'STARR ST',
#  'STATE HIGHWAY 16 S',
#  'WILLIAM D TATE AVE # 100',
#  'COMMERCIAL AVE',
#  'FM 813',
#  'RICHMOND AVE',
#  'W 4TH ST',
#  'E NORTHWEST HWY',
#  'S MASON RD STE 130',
#  'UNDERWOOD RD',
#  'OHIO AVE',
#  '1ST ST W',
#  'S COMMERCE ST',
#  'E 6TH ST',
#  'NACOGDOCHES RD',
#  'WEST FWY STE 100',
#  'W SPRING CREEK PKWY STE 331',
#  'BELLAIRE BLVD UNIT 140301',
#  'GEORGE DIETER DR STE 204',
#  'DIXIE DR',
#  'N LEE TREVINO DR STE 207',
#  'ELM ST',
#  'OLD DENTON RD',
#  'E MAXAN ST',
#  'S LAMAR BLVD',
#  'W JOHN CARPENTER FWY',
#  'N CHURCH ST',
#  'N SAM HOUSTON PKWY W',
#  'N SAM HOUSTON PKWY E',
#  'SW 45TH AVE',
#  'E 8TH ST',
#  'E NEVADA AVE',
#  'S TEXAS AVE',
#  'N MAIN ST',
#  'N MESA ST',
#  'E RED RIVER ST',
#  'TOMBALL PKWY STE A',
#  'N INTERNATIONAL PKWY',
#  'LAKE WORTH BLVD',
#  'S LAMAR BLVD',
#  'FLORA ST',
#  'W SPRING VALLEY RD',
#  'S PADRE ISLAND DR STE 33',
#  'W CROCKETTSTE 101',
#  'HIGHWAY 36 S',
#  'W PARK BLVD',
#  'STATE HIGHWAY 205',
#  'WEDGEWOOD DR',
#  'CULEBRA RD STE 15',
#  'CANYON FALLS BLVD',
#  'N STANTON ST',
#  'S LAMAR BLVD',
#  'FUQUA ST',
#  'CLAY ST',
#  'E HILLSIDE RD',
#  'POST OFFICE ST',
#  'SW 16TH AVE',
#  'BAGPIPER WAY',
#  'NECHES ST',
#  'BIG LEAGUE DREAMS',
#  'S SONCY RD',
#  'US HIGHWAY 180 E',
#  'BROADWAY ST STE D',
#  'S ALAMO ST',
#  'FLOWING WELLS RD',
#  'GRAND AVE',
#  'GREENVILLE AVE',
#  'NW MILITARY HWY',
#  'NORTH FWY',
#  'W ALABAMA ST',
#  'S KIRKWOOD RD STE G',
#  'W 4TH ST STE 111',
#  'RESEARCH FOREST DR STE 420',
#  'WALNUT HILL LN',
#  'SIX PINES RD STE 860',
#  'BROADWAY ST',
#  'S INTERSTATE 35 E',
#  'N OAK AVE',
#  'HEWITT DR STE 100',
#  'S LAMAR BLVD',
#  'BROADDUS AVE',
#  'N EXPRESSWAY # 77',
#  'N VETERANS BLVD STE 100',
#  'INTERSTATE 10 S',
#  'JACKSON KELLER RD',
#  'E 42ND ST',
#  'S PADRE ISLAND DR',
#  'EVERHART ROAD',
#  'BELT LINE RD',
#  'MONTGOMERY ST',
#  'BELTLINE ROAD',
#  'MEDIA LUNA ST STE 800',
#  'COLLEGEST',
#  'TRAVIS ST',
#  'IH 20 WEST',
#  'CHURCH AVE',
#  'WOODWAY DR STE 100',
#  'SAN FELIPE ST STE 100',
#  'E 4TH ST',
#  'TEICHMAN RD',
#  'S INDEPENDENCE ST',
#  'STATE HIGHWAY 26',
#  'LBJ FWY',
#  'N INTERSTATE 35',
#  'W HICKORY ST',
#  'PHELAN BLVD',
#  'E LAMAR BLVD',
#  'WEST RD STE 101',
#  'ALMA RD',
#  'W 4TH ST',
#  'BELT LINE RD STE 108',
#  'EVERHART RD',
#  'E SOUTHLAKE BLVD STE 160',
#  'N LAMAR ST STE 125',
#  'KIRBY DR',
#  'S 17TH ST',
#  'HIGHWAY 75 N',
#  'S BURLESON BLVD',
#  'POTRANCO RD',
#  'SOUTHWEST FWY',
#  'BAY AREA BLVD',
#  'US HIGHWAY 281 N',
#  'W HIGHWAY 114',
#  'CHIMNEY ROCK RD',
#  'MCKINNEY AVE',
#  'ROUGH RIDERS TRL',
#  'GULF FWY',
#  '1/2 HILLCROFT ST',
#  'S LAMAR BLVD',
#  'GREENVILLE AVE',
#  'ELAM RD STE 115',
#  'POND SPRINGS RD STE 301',
#  'E 7TH ST',
#  'SINGLETON BLVD',
#  'N LOOP 1604 E',
#  'AVENUE D STE 100',
#  'BAGBY ST',
#  'JOE RAMSEY BLVD E',
#  'QUAKER AVE',
#  'N INTERSTATE 35 E STE 405',
#  'N L B J DR',
#  'JOSEY LN STE 109',
#  'W INTERSTATE 10 STE 101',
#  'INTERSTATE 10 S',
#  '18TH ST',
#  'WATER WOOD DR',
#  'E INTERSTATE 30',
#  'SOUTHWEST PKWY',
#  'W 6TH ST',
#  'RICHMOND AVE',
#  'PARKER RD BLDG C',
#  'N MAIN AVE',
#  'BELL ST',
#  'HIGHWAY 156',
#  'FREEPORT ST',
#  'EL DORADO BLVD',
#  'LOSOYA ST STE 19',
#  'LAKE ROBBINS DR',
#  'W PARMER LN APT 2128',
#  'N MESA ST',
#  'KISSING TREE LN',
#  'W NORTHWEST HWY STE 100',
#  'W MARSHALL AVE STE A',
#  'N PRESTON SMITH RD',
#  'BAGBY ST',
#  'TEXAS AVE',
#  'DACOMA ST STE A',
#  'DALLAS PKWY STE 100',
#  'W LIVE OAK ST',
#  'N SAINT MARYS ST',
#  'SHANNON ROAD',
#  'MATLOCK RD STE 106',
#  'E CONSTITUTION ST',
#  'GARTH RD',
#  'NEW BOSTON RD',
#  'N STEMMONS FWY',
#  'INTERSTATE 27',
#  'ALMA RD',
#  'KILGORE PLZ',
#  '19TH ST',
#  'SPRING CYPRESS RD',
#  'STATE HIGHWAY 249',
#  'MAIN ST',
#  'SPENCER HWY',
#  'TROPHY CLUB DR',
#  'LONG POINT RD',
#  'KLECKLEY DR STE A',
#  'AVENUE M',
#  'N TANCAHUA ST',
#  'SAN FRANCISCO AVE STE B',
#  'N STORY RD',
#  'N INTERSTATE 35',
#  'PEERLESS ST',
#  'E MAIN ST',
#  'HIGHWAY 6 N',
#  'WESTHEIMER RD',
#  'N GREAT SOUTHWEST PKWY',
#  'SNIDER PLZ',
#  'PAVILLION CT',
#  'IH 35 S',
#  '4TH ST',
#  'WONDER ST',
#  'HOUSTON AVE',
#  'FORT WORTH AVE',
#  'LEGACY DR STE B1',
#  'CHENEVERT ST STE N',
#  'E STATE HIGHWAY 159',
#  'BOMAR ST',
#  'W VETERANS MEMORIAL BLVD',
#  'S 1ST ST',
#  'N LOOP 1604 E',
#  'GREENWOOD ST',
#  'WESTHEIMER RD',
#  'FM 1960 RD W',
#  'POST OFFICE ST',
#  'KINGSLEY RD  #104',
#  'LEBANON RD',
#  'ALMA ST STE A-B',
#  'VIRGINIA ST',
#  'POST OFFICE ST',
#  'E 6TH ST',
#  'GREEN OAKS RD STE B&C',
#  'N WATSON RD',
#  'W EXPRESSWAY 83 STE 105110',
#  'HIGHWAY 80 W',
#  'S GULF BLVD',
#  'N EL PASO ST',
#  'W INTERSTATE 10 # 111',
#  'DUNVALE RD',
#  'GULF FWY',
#  'E VETERANS MEMORIAL BLVD',
#  'GEORGE DIETER DR STE 204',
#  'LITTLE RD STE 101',
#  'COIT RD STE 250',
#  'W DAVIS ST',
#  'N STATE HIGHWAY 349',
#  'CLUB DR',
#  'N LOOP 1604 W # NORTH',
#  'E SAUNDERS ST',
#  'CYPRESS ROSEHILL RD STE 160',
#  'W LYNDON B JOHNSON FWY',
#  'MCPHERSON RD',
#  'SEARS ST',
#  'ALTA MERE DR',
#  'AIRPORT RD',
#  'E DAVIS ST STE 104',
#  'N LEE TREVINO DR',
#  'S COLLEGE AVE',
#  'SAM HOUSTON AVE',
#  'KINGSLAND BLVD',
#  'STATE HWY 114 EAST',
#  'S MAIN ST',
#  'N VALLEY MILLS DR',
#  'EAGLE ST',
#  'JUDSON RD STE 101',
#  'JUSTIN RD STE 180',
#  'STEPHEN F AUSTIN DR',
#  'HIGHWAY 59 N',
#  'MAIN',
#  'STATE HIGHWAY 249',
#  'E SAM HOUSTON PKWY N',
#  'MCPHERSON RD',
#  'SUNMOUNT DR',
#  'STONELAKE BLVD',
#  'E 9TH ST',
#  'AVENUE Q',
#  'E HOUSTON ST',
#  'WESTERN AVE',
#  'TIMMONS LN',
#  'SPRING GREEN BLVD STE 400',
#  'BOYETT ST',
#  'KELLER SPRINGS RD',
#  'E 24TH ST',
#  'N INTERSTATE 35',
#  'N INTERSTATE 35',
#  'CRYSTAL SPGS',
#  'NORTH FWY STE 500',
#  'GRAND AVE',
#  'AVENIDA DE LAS AMERICAS',
#  'GREYSTONE DR',
#  'S 7TH ST',
#  'MARSH LN STE 109',
#  '19TH ST',
#  'OLIVE ST',
#  'E EXPRESSWAY 83 UNIT 1235',
#  'GARTH RD',
#  'S TERMINAL RD TERMINAL E STE TE-UC',
#  'CAMP BOWIE W',
#  'W ROYAL LN',
#  'BEE CAVES RD',
#  'E LOOP 281 STE B',
#  'LOCKHILL SELMA RD # 106',
#  'N MIDKIFF RD STE 160',
#  'W BROAD ST',
#  'MIDWAY RD STE 600',
#  'W HICKORY ST',
#  'NORTH FWY',
#  'DALLAS PKWY STE 100',
#  'FM 344 E',
#  'S CONGRESS AVE',
#  'W COMMERCE ST',
#  'BANDERA HWY',
#  'FM 685 # B',
#  'FM 2673',
#  'SARATOGA BLVD',
#  'MACARTHUR PARK',
#  'TARPON ST',
#  'RUFE SNOW DR STE 209',
#  'FM 1464 RD',
#  'E BASSE RD',
#  'FM 3351 S STE 100',
#  'MCNEIL RD STE 112',
#  'SPRING GREEN BLVD STE 400',
#  'NE LOOP 410',
#  'S STEMMONS FWY',
#  'OVELLA AVE',
#  'W 7TH ST',
#  'SHADOW MOUNTAIN DR STE A',
#  'LYNDON B JOHNSON FWY',
#  'MILWAUKEE AVE',
#  'FM 306 # 4A',
#  'ELDRIDGE PKWY STE A',
#  '82ND ST',
#  'TWIN CREEKS DR',
#  'GREENSPOINT DR',
#  'HARRY HINES',
#  'W 7TH ST',
#  'S INTERSTATE 35 E # 31',
#  'HIGHWAY 80 W',
#  'UTSA BLVD STE 109',
#  'N LOCUST ST',
#  'GLENMONT DR',
#  'MAIN ST STE 245',
#  'MARKET ST',
#  'LEEWARD DR # 101103',
#  'BELT LINE RD STE 200',
#  'W HOUSTON ST',
#  'S SAM HOUSTON BLVD',
#  'S STEWART ST',
#  'PEARL PKWY BLDG 2',
#  'W MAIN ST',
#  'MACO DR',
#  'RICHEY ST',
#  'OLD DENTON RD STE 400',
#  'US HIGHWAY 77A N',
#  'CROSS ROADS DR',
#  'AIRPORT FWY',
#  'ROCK ROSE AVE STE Y4.100',
#  'SAN JACINTO ST',
#  'S INTERSTATE 35',
#  'HIGHWAY 146 STE E',
#  'HWY 180 EAST',
#  'W NORTHWEST HWY',
#  'E BEN WHITE BLVD',
#  'CENTRAL EXPY STE 600',
#  'NORTHWEST FWY STE 190',
#  'W IH 10',
#  'TEXAS ST',
#  'AVENUE S',
#  'W PIPELINE RD',
#  'S BAYLOR ST',
#  'REBECCA CREEK RD',
#  'SW WILSHIRE BLVD STE 600',
#  'VETERANS MEMORIAL DR',
#  'W INTERSTATE 20',
#  'LA CANTERA PKWY',
#  'FM 16 W',
#  'W DAVIS ST',
#  'S LAMAR BLVD',
#  'BYRON NELSON PKWY',
#  'E 6TH ST # A-D',
#  'SAN PEDRO AVE',
#  'W 6TH ST STE 2100',
#  'N SPUR 63',
#  'E HIGHWAY 190',
#  'RUIDOSA AVE',
#  'SOUTHWEST FWY',
#  'GATEWAY BLVD E',
#  'KATY FWY',
#  'W NORTH LOOP BLVD STE G',
#  'NORTH WEST LOOP 281',
#  'W IH 635 FWY',
#  'NW MILITARY HWY',
#  'W WASHINGTON ST',
#  'COUNTRY CLUB DR',
#  'CLEAR LAKE CITY BLVD UNIT G',
#  'WINROCK BLVD',
#  'BROADWAY ST',
#  'N INTERSTATE HIGHWAY 35 E',
#  'W WILLIAM CANNON DR',
#  'N BELT LINE RD STE A',
#  'ROSS AVE',
#  'LOUETTA RD',
#  'BROADWAY ST',
#  'W VETERANS MEMORIAL BLVD',
#  'W INTERSTATE 40',
#  'AIRPORT RD',
#  'E NOLANA AVE',
#  'N MOCKINGBIRD LN',
#  'LEGACY DR STE B7',
#  'SEAWALL BLVD',
#  'HIGHWAY 6 N',
#  'W 4TH ST',
#  'FALCONHEAD BLVD',
#  'OAK LAWN AVE',
#  'N MAIN ST',
#  'S WASHINGTON ST',
#  'E PRINCETON DR STE 102',
#  'LAS COLINAS BLVD W',
#  'STATE HIGHWAY 249',
#  'KATY FWY STE L',
#  'SOUTHWEST FWY',
#  'COLORADO ST STE B',
#  'S POLK ST',
#  'SAN JACINTO BLVD STE 200',
#  'KUYKENDAHL RD STE A',
#  'SOUTHVIEW CIR',
#  'DESSAU RD',
#  'N 10TH ST',
#  'S EXPRESSWAY 83',
#  'NE LOOP 820',
#  'N COIT RD STE 260',
#  'E LANCASTER AVE',
#  'FM 1670',
#  'US HIGHWAY 281 N',
#  'LAKE JUNE RD',
#  'W HWY 377',
#  'E 6TH ST',
#  'GULF FWY',
#  'S GUN BARREL LN',
#  'W LOOP 250 N',
#  'W AIRPORT BLVD STE 10',
#  'DOMAIN DR STE 200',
#  'S COLORADO ST STE 110',
#  'ROSEMEADE PKWY STE 100',
#  'E 6TH ST',
#  'TOWN AND COUNTRY BLVD',
#  'MAIN 39TH & 40TH FLS CONTINENTAL PLA',
#  'N CENTRAL EXPY',
#  'MAIN ST STE 6900',
#  'S 10TH ST',
#  'VANTAGE POINT DR',
#  'W INTERSTATE 10',
#  'CENTER AVE',
#  'GREENVILLE AVE',
#  'RR 620 S STE A100',
#  'GATEWAY BLVD E',
#  'N MAYS ST',
#  'CLUB ESTATES PKWY',
#  'WEBB CHAPEL RD',
#  '25TH ST',
#  'N JUPITER RD',
#  'W LOVERS LN STE 112B',
#  'WEBBERVILLE RD',
#  'COACHLIGHT ST',
#  'GULF FWY',
#  'E MAIN ST',
#  'E HWY 82',
#  'W INTERSTATE 40',
#  'WESTHEIMER RD STE 210A',
#  'KEMAH WATERFRONT ST',
#  'LEMMON AVE # 176',
#  'PLANTATION DR STE 100',
#  'SHILOH DR STE 0',
#  'E LAMAR BLVD',
#  'GEORGE DIETER DR STE 105',
#  'S SONCY RD',
#  'SAN FELIPE ST STE 100',
#  'WEST FWY',
#  'WESTHEIMER RD STE 160',
#  'WESTHEIMER RD',
#  'NORTH LOOP E',
#  'S STEMMONS FWY',
#  'CANYON DR',
#  'N MAY ST',
#  'ANDREWS HWY',
#  'BOULEVARD ST',
#  'E MAIN ST',
#  'S 20TH ST',
#  'E END BLVD S',
#  'SE 23RD ST',
#  'N MAIN',
#  'UP RIVER RD',
#  'N MILLBEND DR',
#  'SPRING CYPRESS RD',
#  'N MESA ST STE H',
#  'MARSHA SHARP FWY',
#  'COIT RD STE 396',
#  'E HEBRON PKWY',
#  'E PECAN ST STE 125',
#  'N LEE TREVINO DR',
#  'EARLY BLVD',
#  'JACK NICKLAUS DR',
#  'S JACKSON RD',
#  'I H 45 S',
#  'AIRPORT RD',
#  'N LOOP 1604 W STE 105',
#  'N GRAND AVE',
#  'S PADRE ISLAND DR',
#  'N EXPRESSWAY',
#  'COIT RD STE A',
#  'BENSDALE RD',
#  'SAMUELL BLVD',
#  'E ARKANSAS LN STE 335',
#  'OLD BULLARD RD',
#  'POST OAK BLVD STE 164',
#  'E OLTORF ST STE 16',
#  'RED RIVER ST',
#  'N BUCKNER BLVD STE 108',
#  'S HIGHWAY 146',
#  'GEORGE DIETER DR STE 204',
#  'TEXOMA PKWY',
#  'ELLSWORTH DR',
#  'STATE HIGHWAY 35 N',
#  'E BELT LINE RD STE 138',
#  'EMERALD ST STE 108',
#  'W AIRPORT BLVD',
#  'S STEMMONS FWY',
#  'GREENVILLE AVE',
#  'MONTANA AVE',
#  'FANNIN ST',
#  'GREENVILLE AVE',
#  'SHOPS PKWY',
#  'E BEN WHITE BLVD',
#  'W PARSONS ST',
#  'GULF FWY',
#  'AIRPORT RD STE B',
#  'N STEMMONS FWY STE 100',
#  'MAPLE AVE',
#  'S ROBB ST',
#  'S COOPER ST',
#  'W BEDFORD EULESS RD',
#  'N LOOP 1604 W STE 1101',
#  'N MAIN ST',
#  'KILGORE PLZ',
#  'N COIT ROAD #270',
#  'BOWIE',
#  'POINTE WEST DR',
#  'IH 10 W',
#  'WESTHEIMER RD',
#  'W GRAND ST',
#  '57TH ST STE 100',
#  'MCKINNEY AVE',
#  'OLD BULLARD RD STE 500',
#  'NORTHWEST FWY',
#  'E SAM HOUSTON PKWY N',
#  'E BASSE RD STE 1400',
#  'RALPH ST',
#  'HARVEY RD',
#  'S WASHINGTON AVE',
#  'N 6TH ST',
#  'WESTHEIMER RD',
#  'TIDWELL RD STE J',
#  'LOUETTA RD STE F',
#  'E DEL MAR BLVD STE 106',
#  '82ND ST',
#  'S MAIN ST',
#  'GEORGE DIETER DR STE 204',
#  'W LOOP 289',
#  'BANDERA RD',
#  'PRESIDENTIAL BLVD STE 5',
#  'KIRBY DR',
#  'AIRLINE RD STE 115',
#  'FM 3005 RD',
#  'FM 1765',
#  'NE VINE ST',
#  'ROAD TO SIX FLAGS ST E STE 103',
#  'PALMER HWY',
#  'BROADWAY ST',
#  'DOVE HOLLOW TRL',
#  'KENNEY ST',
#  'INTERSTATE 20 W',
#  'RESEARCH BLVD STE 100',
#  'S JACKSON RD STE 7',
#  'TEXAS AVE',
#  'BRAESWOOD SQ',
#  'S CHADBOURNE ST',
#  'WESTHEIMER RD STE 1010',
#  'HWY 46 E',
#  'INTERSTATE 35 N',
#  'E LEAGUE CITY PKWY STE 123',
#  'MARKET ST',
#  'WOODFOREST BLVD',
#  'N INTERNATIONAL PKWY',
#  'WOODWAY DR',
#  'W MCDERMOTT DR',
#  'BISSONNET ST',
#  'E LOUISIANA ST',
#  'E NASA PKWY STE 140',
#  'SAMUELL BLVD',
#  'W PANOLA ST',
#  'E HOPKINS ST',
#  'N KINGS HWY',
#  'W AMARILLO BLVD',
#  'N TEXAS BLVD',
#  'E HOUSTON ST',
#  'HIGHWAY 365 STE 172',
#  'S ALAMO',
#  'COUNTY ROAD 268',
#  'PRESTON RD',
#  'DALLAS PKWY',
#  'AUGUSTA PINES DR',
#  'SIMOND AVE STE 100',
#  'FM 3277',
#  'W ADAMS AVE',
#  'NAVIGATION CIR',
#  'HARRY HINES BLVD',
#  'COIT RD STE 396',
#  'KATY FWY',
#  'E RENNER RD STE 128',
#  'E HIGHWAY 377',
#  'FM 2978 RD',
#  'GREENVILLE AVE',
#  'MAIN ST',
#  'W 4TH ST # A',
#  'KINGWOOD DR',
#  'S STEMMONS FWY',
#  'WESTHEIMER RD STE 151',
#  'JAMES WATT DR',
#  'NORTHWEST HWY STE C',
#  'S CAPITAL OF TEXAS HWY SPC G02B',
#  'BRODIE LN STE 900',
#  'TELGE RD',
#  '4TH ST',
#  'E RUSK ST',
#  'COMMERCE ST',
#  'N ESPLANADE ST',
#  'S GENERAL BRUCE DR',
#  'PINE ST',
#  'N MAIN ST',
#  'SUNSET DR',
#  'ROSS AVE STE 100',
#  'W CENTER ST',
#  'NORTHWEST FWY',
#  'S CAPITAL OF TEXAS HWY',
#  'FRANKLIN AVE',
#  'HIGHWAY 6',
#  'QUEBEC ST',
#  'E MOCKINGBIRD LN',
#  'SOUTHWEST PKWY STE 101',
#  'I 45 N STE 3',
#  'N HIGHWAY 183 BLDG E',
#  'PERKINS AVE STE A',
#  'N MESA ST',
#  'NORTHWEST FWY',
#  'SYDNOR LN',
#  'E 6TH ST',
#  'AVENUE Q STE B',
#  'BROADWAY ST STE 101',
#  'N OAK AVE',
#  'VINTAGE PARK BLVD STE Q',
#  'E ARKANSAS LN STE 335',
#  'N MAIN ST',
#  'LINCOLN SQ',
#  'LOMO ALTO DR']

# %%
address_streets[:4]
# ['HARRY HINES BLVD', 'PABLO KISEL BLVD STE N',
# 'W HWY 71', 'SLIDE RD STE 100']
# Out:
# ['HARRY HINES BLVD', 'PABLO KISEL BLVD STE N', 'W HWY 71', 'SLIDE RD STE 100']

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lesson, we saw how we can use split and join to coerce our string data.  We also reinforced our process of first solving a problem on just one element, and then moving to solving the same problem on each element in a loop.
