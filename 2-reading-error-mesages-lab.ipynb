# %% [markdown]
# # Reading Error Messages Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, we'll practice reading our error messages.  Let's get started.

# %% [markdown]
# ### Loading our Data

# %% [markdown]
# Let's load our data, but not look at any of the error messages.  Instead, we would just like to read the error messages, and understand what is occurring.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/eng-6-22/mod-1-a-data-structures/master/0-programming-patterns/polls.csv"
df = pd.read_csv(url)
records = df.to_dict('records')

records
# Out:
# [{'Unnamed: 0': 0,
#   'cycle': 2016,
#   'state': 'Alabama',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 70.11138,
#   'pct_trend_adjusted': 68.63747,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 66,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 70.111381,
#   'trend_shortpoly0': 68.637474,
#   'sum_weight_medium': 1.293506,
#   'sum_weight_short': 1.293506,
#   'sum_influence': 1.293506,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 1,
#   'cycle': 2016,
#   'state': 'Alaska',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 51.63014,
#   'pct_trend_adjusted': 49.68174,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 51.630138,
#   'trend_shortpoly0': 49.681736,
#   'sum_weight_medium': 0.8274046,
#   'sum_weight_short': 0.8274046,
#   'sum_influence': 0.8274046,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 2,
#   'cycle': 2016,
#   'state': 'Arizona',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 44.0,
#   'pct_trend_adjusted': 41.02212,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 30,
#   'last_enddate': '12/9/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 44.0,
#   'trend_shortpoly0': 41.022121,
#   'sum_weight_medium': 0.8299773,
#   'sum_weight_short': 0.8299773,
#   'sum_influence': 0.8299773,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 3,
#   'cycle': 2016,
#   'state': 'Colorado',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 45.9515,
#   'pct_trend_adjusted': 43.51193,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 113,
#   'last_enddate': '2/29/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 45.951502,
#   'trend_shortpoly0': 43.511929,
#   'sum_weight_medium': 2.209496,
#   'sum_weight_short': 2.209496,
#   'sum_influence': 1.012831,
#   'sum_nat_influence': 0.6910744,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 4,
#   'cycle': 2016,
#   'state': 'Florida',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 46.54603,
#   'pct_trend_adjusted': 44.68674,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 110,
#   'last_enddate': '2/25/2016',
#   '_medpoly2': 47.394218,
#   'trend_medpoly2': 46.558936,
#   '_shortpoly0': 46.376394,
#   'trend_shortpoly0': 44.312304,
#   'sum_weight_medium': 4.328866,
#   'sum_weight_short': 4.328866,
#   'sum_influence': 2.770836,
#   'sum_nat_influence': 0.9420227,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 5,
#   'cycle': 2016,
#   'state': 'Georgia',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 49.98361,
#   'pct_trend_adjusted': 49.4803,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 108,
#   'last_enddate': '2/23/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 49.983612,
#   'trend_shortpoly0': 49.480297,
#   'sum_weight_medium': 1.775305,
#   'sum_weight_short': 1.775305,
#   'sum_influence': 1.775305,
#   'sum_nat_influence': 1.194635,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 6,
#   'cycle': 2016,
#   'state': 'Illinois',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 27.5,
#   'pct_trend_adjusted': 25.70271,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/9/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 27.500001,
#   'trend_shortpoly0': 25.702706,
#   'sum_weight_medium': 0.7289574,
#   'sum_weight_short': 0.7289574,
#   'sum_influence': 0.7289574,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 7,
#   'cycle': 2016,
#   'state': 'Iowa',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 43.1852,
#   'pct_trend_adjusted': 41.14408,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/10/2016',
#   '_medpoly2': 43.198731,
#   'trend_medpoly2': 41.433503,
#   '_shortpoly0': 43.182495,
#   'trend_shortpoly0': 41.086191,
#   'sum_weight_medium': 5.338463,
#   'sum_weight_short': 5.338463,
#   'sum_influence': 4.136615,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 8,
#   'cycle': 2016,
#   'state': 'Kansas',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 50.45541,
#   'pct_trend_adjusted': 49.83593,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 108,
#   'last_enddate': '2/26/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 50.455414,
#   'trend_shortpoly0': 49.83593,
#   'sum_weight_medium': 0.3886382,
#   'sum_weight_short': 0.3886382,
#   'sum_influence': 0.3886382,
#   'sum_nat_influence': 0.2615218,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 9,
#   'cycle': 2016,
#   'state': 'Michigan',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 38.922,
#   'pct_trend_adjusted': 38.48544,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 116,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': 38.488217,
#   'trend_medpoly2': 38.344093,
#   '_shortpoly0': 39.008763,
#   'trend_shortpoly0': 38.513705,
#   'sum_weight_medium': 4.180455,
#   'sum_weight_short': 4.180455,
#   'sum_influence': 3.278449,
#   'sum_nat_influence': 3.134945,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 10,
#   'cycle': 2016,
#   'state': 'Minnesota',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 40.25981,
#   'pct_trend_adjusted': 38.38002,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 73,
#   'last_enddate': '1/20/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 40.259812,
#   'trend_shortpoly0': 38.380024,
#   'sum_weight_medium': 1.084677,
#   'sum_weight_short': 1.084677,
#   'sum_influence': 1.084677,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 11,
#   'cycle': 2016,
#   'state': 'Montana',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 55.84407,
#   'pct_trend_adjusted': 52.12106,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 13,
#   'last_enddate': '11/23/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 55.844066,
#   'trend_shortpoly0': 52.121059,
#   'sum_weight_medium': 0.4694052,
#   'sum_weight_short': 0.4694052,
#   'sum_influence': 0.4694052,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 12,
#   'cycle': 2016,
#   'state': 'National',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 42.9214,
#   'pct_trend_adjusted': 42.44001,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 115,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': 42.447379,
#   'trend_medpoly2': 42.386132,
#   '_shortpoly0': 43.395429,
#   'trend_shortpoly0': 42.493883,
#   'sum_weight_medium': 54.51669,
#   'sum_weight_short': 62.48756,
#   'sum_influence': 8.461908,
#   'sum_nat_influence': 8.461908,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 13,
#   'cycle': 2016,
#   'state': 'Nevada',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 46.28437,
#   'pct_trend_adjusted': 41.72754,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 6,
#   'last_enddate': '11/16/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 46.284366,
#   'trend_shortpoly0': 41.727535,
#   'sum_weight_medium': 0.7816904,
#   'sum_weight_short': 0.7816904,
#   'sum_influence': 0.7816904,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 14,
#   'cycle': 2016,
#   'state': 'New Hampshire',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 41.26325,
#   'pct_trend_adjusted': 39.64256,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 109,
#   'last_enddate': '2/28/2016',
#   '_medpoly2': 40.440873,
#   'trend_medpoly2': 39.552022,
#   '_shortpoly0': 41.427723,
#   'trend_shortpoly0': 39.660664,
#   'sum_weight_medium': 9.321606,
#   'sum_weight_short': 9.321606,
#   'sum_influence': 3.470526,
#   'sum_nat_influence': 0.8122557,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 15,
#   'cycle': 2016,
#   'state': 'New Jersey',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 38.23107,
#   'pct_trend_adjusted': 37.87658,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 111,
#   'last_enddate': '2/28/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 38.231072,
#   'trend_shortpoly0': 37.876576,
#   'sum_weight_medium': 1.059748,
#   'sum_weight_short': 1.059748,
#   'sum_influence': 1.059748,
#   'sum_nat_influence': 0.8616768,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 16,
#   'cycle': 2016,
#   'state': 'New York',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 35.19905,
#   'pct_trend_adjusted': 34.54594,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 115,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 35.199056,
#   'trend_shortpoly0': 34.545939,
#   'sum_weight_medium': 2.292912,
#   'sum_weight_short': 2.393991,
#   'sum_influence': 1.376205,
#   'sum_nat_influence': 1.175688,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 17,
#   'cycle': 2016,
#   'state': 'North Carolina',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 44.26028,
#   'pct_trend_adjusted': 43.30642,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 102,
#   'last_enddate': '2/19/2016',
#   '_medpoly2': 43.419103,
#   'trend_medpoly2': 42.84673,
#   '_shortpoly0': 44.428513,
#   'trend_shortpoly0': 43.398352,
#   'sum_weight_medium': 7.017797,
#   'sum_weight_short': 7.017797,
#   'sum_influence': 5.563706,
#   'sum_nat_influence': 1.608383,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 18,
#   'cycle': 2016,
#   'state': 'Ohio',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 43.62766,
#   'pct_trend_adjusted': 43.08505,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 103,
#   'last_enddate': '2/20/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 43.627659,
#   'trend_shortpoly0': 43.085048,
#   'sum_weight_medium': 2.498985,
#   'sum_weight_short': 2.498985,
#   'sum_influence': 2.428324,
#   'sum_nat_influence': 1.015099,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 19,
#   'cycle': 2016,
#   'state': 'Pennsylvania',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 42.75623,
#   'pct_trend_adjusted': 42.34789,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 116,
#   'last_enddate': '3/2/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.756226,
#   'trend_shortpoly0': 42.347888,
#   'sum_weight_medium': 1.499532,
#   'sum_weight_short': 1.499532,
#   'sum_influence': 1.172013,
#   'sum_nat_influence': 1.186391,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 20,
#   'cycle': 2016,
#   'state': 'South Carolina',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 46.28437,
#   'pct_trend_adjusted': 42.67881,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 6,
#   'last_enddate': '11/16/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 46.284366,
#   'trend_shortpoly0': 42.67881,
#   'sum_weight_medium': 0.7809128,
#   'sum_weight_short': 0.7809128,
#   'sum_influence': 0.7809128,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 21,
#   'cycle': 2016,
#   'state': 'Texas',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 46.98365,
#   'pct_trend_adjusted': 46.2808,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 107,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 46.983646,
#   'trend_shortpoly0': 46.280804,
#   'sum_weight_medium': 1.799316,
#   'sum_weight_short': 1.799316,
#   'sum_influence': 1.799316,
#   'sum_nat_influence': 1.126718,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 22,
#   'cycle': 2016,
#   'state': 'Utah',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 37.2043,
#   'pct_trend_adjusted': 34.74948,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 34,
#   'last_enddate': '12/14/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 37.204296,
#   'trend_shortpoly0': 34.749477,
#   'sum_weight_medium': 0.5865651,
#   'sum_weight_short': 0.5865651,
#   'sum_influence': 0.5865651,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 23,
#   'cycle': 2016,
#   'state': 'Virginia',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 37.47325,
#   'pct_trend_adjusted': 35.77851,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 105,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': 37.289689,
#   'trend_medpoly2': 36.495688,
#   '_shortpoly0': 37.509958,
#   'trend_shortpoly0': 35.635076,
#   'sum_weight_medium': 2.093773,
#   'sum_weight_short': 2.093773,
#   'sum_influence': 1.360229,
#   'sum_nat_influence': 0.3894523,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 24,
#   'cycle': 2016,
#   'state': 'West Virginia',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 61.0,
#   'pct_trend_adjusted': 60.41967,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 107,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 61.0,
#   'trend_shortpoly0': 60.419666,
#   'sum_weight_medium': 0.5626372,
#   'sum_weight_short': 0.5626372,
#   'sum_influence': 0.5626372,
#   'sum_nat_influence': 0.3523191,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 25,
#   'cycle': 2016,
#   'state': 'Wisconsin',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 39.85077,
#   'pct_trend_adjusted': 38.14385,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 105,
#   'last_enddate': '2/21/2016',
#   '_medpoly2': 39.553864,
#   'trend_medpoly2': 38.729296,
#   '_shortpoly0': 39.910153,
#   'trend_shortpoly0': 38.026762,
#   'sum_weight_medium': 3.306806,
#   'sum_weight_short': 3.306806,
#   'sum_influence': 2.057189,
#   'sum_nat_influence': 0.574262,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 26,
#   'cycle': 2016,
#   'state': 'Alabama',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 32.67097,
#   'pct_trend_adjusted': 32.84491,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 66,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 32.670974,
#   'trend_shortpoly0': 32.844913,
#   'sum_weight_medium': 1.293506,
#   'sum_weight_short': 1.293506,
#   'sum_influence': 1.293506,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 27,
#   'cycle': 2016,
#   'state': 'Alaska',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.82401,
#   'pct_trend_adjusted': 45.08152,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 44.824013,
#   'trend_shortpoly0': 45.081524,
#   'sum_weight_medium': 0.8274046,
#   'sum_weight_short': 0.8274046,
#   'sum_influence': 0.8274046,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 28,
#   'cycle': 2016,
#   'state': 'Arizona',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 42.0,
#   'pct_trend_adjusted': 40.0138,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 30,
#   'last_enddate': '12/9/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.0,
#   'trend_shortpoly0': 40.013798,
#   'sum_weight_medium': 0.8299773,
#   'sum_weight_short': 0.8299773,
#   'sum_influence': 0.8299773,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 29,
#   'cycle': 2016,
#   'state': 'Colorado',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 42.03014,
#   'pct_trend_adjusted': 41.31678,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 113,
#   'last_enddate': '2/29/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.030141,
#   'trend_shortpoly0': 41.31678,
#   'sum_weight_medium': 2.209496,
#   'sum_weight_short': 2.209496,
#   'sum_influence': 1.012831,
#   'sum_nat_influence': 0.6910744,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 30,
#   'cycle': 2016,
#   'state': 'Florida',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.90705,
#   'pct_trend_adjusted': 44.34629,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 110,
#   'last_enddate': '2/25/2016',
#   '_medpoly2': 44.525869,
#   'trend_medpoly2': 44.386938,
#   '_shortpoly0': 44.983282,
#   'trend_shortpoly0': 44.338154,
#   'sum_weight_medium': 4.328866,
#   'sum_weight_short': 4.328866,
#   'sum_influence': 2.770836,
#   'sum_nat_influence': 0.9420227,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 31,
#   'cycle': 2016,
#   'state': 'Georgia',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 41.02863,
#   'pct_trend_adjusted': 40.96251,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 108,
#   'last_enddate': '2/23/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 41.028633,
#   'trend_shortpoly0': 40.962509,
#   'sum_weight_medium': 1.775305,
#   'sum_weight_short': 1.775305,
#   'sum_influence': 1.775305,
#   'sum_nat_influence': 1.194635,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 32,
#   'cycle': 2016,
#   'state': 'Illinois',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 36.5,
#   'pct_trend_adjusted': 36.77266,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/9/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 36.5,
#   'trend_shortpoly0': 36.772659,
#   'sum_weight_medium': 0.7289574,
#   'sum_weight_short': 0.7289574,
#   'sum_influence': 0.7289574,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 33,
#   'cycle': 2016,
#   'state': 'Iowa',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 45.31864,
#   'pct_trend_adjusted': 45.08527,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/10/2016',
#   '_medpoly2': 45.157377,
#   'trend_medpoly2': 45.484846,
#   '_shortpoly0': 45.350893,
#   'trend_shortpoly0': 45.005355,
#   'sum_weight_medium': 5.338463,
#   'sum_weight_short': 5.338463,
#   'sum_influence': 4.136615,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 34,
#   'cycle': 2016,
#   'state': 'Kansas',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 37.2351,
#   'pct_trend_adjusted': 37.17752,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 108,
#   'last_enddate': '2/26/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 37.235096,
#   'trend_shortpoly0': 37.17752,
#   'sum_weight_medium': 0.3886382,
#   'sum_weight_short': 0.3886382,
#   'sum_influence': 0.3886382,
#   'sum_nat_influence': 0.2615218,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 35,
#   'cycle': 2016,
#   'state': 'Michigan',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 48.94632,
#   'pct_trend_adjusted': 48.92916,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 116,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': 50.331258,
#   'trend_medpoly2': 50.332246,
#   '_shortpoly0': 48.669327,
#   'trend_shortpoly0': 48.648538,
#   'sum_weight_medium': 4.180455,
#   'sum_weight_short': 4.180455,
#   'sum_influence': 3.278449,
#   'sum_nat_influence': 3.134945,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 36,
#   'cycle': 2016,
#   'state': 'Minnesota',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 43.72152,
#   'pct_trend_adjusted': 43.61113,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 73,
#   'last_enddate': '1/20/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 43.721515,
#   'trend_shortpoly0': 43.611126,
#   'sum_weight_medium': 1.084677,
#   'sum_weight_short': 1.084677,
#   'sum_influence': 1.084677,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 37,
#   'cycle': 2016,
#   'state': 'Montana',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 31.16828,
#   'pct_trend_adjusted': 29.85276,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 13,
#   'last_enddate': '11/23/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 31.168275,
#   'trend_shortpoly0': 29.852756,
#   'sum_weight_medium': 0.4694052,
#   'sum_weight_short': 0.4694052,
#   'sum_influence': 0.4694052,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 38,
#   'cycle': 2016,
#   'state': 'National',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 47.38879,
#   'pct_trend_adjusted': 47.13026,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 115,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': 47.482154,
#   'trend_medpoly2': 47.201392,
#   '_shortpoly0': 47.295415,
#   'trend_shortpoly0': 47.05913,
#   'sum_weight_medium': 54.51669,
#   'sum_weight_short': 62.48756,
#   'sum_influence': 8.461908,
#   'sum_nat_influence': 8.461908,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 39,
#   'cycle': 2016,
#   'state': 'Nevada',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 42.14902,
#   'pct_trend_adjusted': 40.59892,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 6,
#   'last_enddate': '11/16/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.149017,
#   'trend_shortpoly0': 40.598915,
#   'sum_weight_medium': 0.7816904,
#   'sum_weight_short': 0.7816904,
#   'sum_influence': 0.7816904,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 40,
#   'cycle': 2016,
#   'state': 'New Hampshire',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 46.90771,
#   'pct_trend_adjusted': 46.53025,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 109,
#   'last_enddate': '2/28/2016',
#   '_medpoly2': 46.213225,
#   'trend_medpoly2': 45.880746,
#   '_shortpoly0': 47.046604,
#   'trend_shortpoly0': 46.660153,
#   'sum_weight_medium': 9.321606,
#   'sum_weight_short': 9.321606,
#   'sum_influence': 3.470526,
#   'sum_nat_influence': 0.8122557,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 41,
#   'cycle': 2016,
#   'state': 'New Jersey',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 52.72868,
#   'pct_trend_adjusted': 52.72894,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 111,
#   'last_enddate': '2/28/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 52.728676,
#   'trend_shortpoly0': 52.728939,
#   'sum_weight_medium': 1.059748,
#   'sum_weight_short': 1.059748,
#   'sum_influence': 1.059748,
#   'sum_nat_influence': 0.8616768,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 42,
#   'cycle': 2016,
#   'state': 'New York',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 57.71964,
#   'pct_trend_adjusted': 57.55657,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 115,
#   'last_enddate': '3/3/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 57.719635,
#   'trend_shortpoly0': 57.556568,
#   'sum_weight_medium': 2.292912,
#   'sum_weight_short': 2.393991,
#   'sum_influence': 1.376205,
#   'sum_nat_influence': 1.175688,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 43,
#   'cycle': 2016,
#   'state': 'North Carolina',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.42224,
#   'pct_trend_adjusted': 44.09425,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 102,
#   'last_enddate': '2/19/2016',
#   '_medpoly2': 44.725157,
#   'trend_medpoly2': 44.543866,
#   '_shortpoly0': 44.36166,
#   'trend_shortpoly0': 44.004333,
#   'sum_weight_medium': 7.017797,
#   'sum_weight_short': 7.017797,
#   'sum_influence': 5.563706,
#   'sum_nat_influence': 1.608383,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 44,
#   'cycle': 2016,
#   'state': 'Ohio',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 40.64627,
#   'pct_trend_adjusted': 40.60757,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 103,
#   'last_enddate': '2/20/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 40.646266,
#   'trend_shortpoly0': 40.607575,
#   'sum_weight_medium': 2.498985,
#   'sum_weight_short': 2.498985,
#   'sum_influence': 2.428324,
#   'sum_nat_influence': 1.015099,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 45,
#   'cycle': 2016,
#   'state': 'Pennsylvania',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.8965,
#   'pct_trend_adjusted': 44.84734,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 116,
#   'last_enddate': '3/2/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 44.896504,
#   'trend_shortpoly0': 44.847338,
#   'sum_weight_medium': 1.499532,
#   'sum_weight_short': 1.499532,
#   'sum_influence': 1.172013,
#   'sum_nat_influence': 1.186391,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 46,
#   'cycle': 2016,
#   'state': 'South Carolina',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 42.14902,
#   'pct_trend_adjusted': 40.84846,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 6,
#   'last_enddate': '11/16/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.149017,
#   'trend_shortpoly0': 40.848465,
#   'sum_weight_medium': 0.7809128,
#   'sum_weight_short': 0.7809128,
#   'sum_influence': 0.7809128,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 47,
#   'cycle': 2016,
#   'state': 'Texas',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.02897,
#   'pct_trend_adjusted': 43.90934,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 107,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 44.028969,
#   'trend_shortpoly0': 43.90934,
#   'sum_weight_medium': 1.799316,
#   'sum_weight_short': 1.799316,
#   'sum_influence': 1.799316,
#   'sum_nat_influence': 1.126718,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 48,
#   'cycle': 2016,
#   'state': 'Utah',
#   'modeldate': '3/3/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 29.14013,
#   'pct_trend_adjusted': 27.61069,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 34,
#   'last_enddate': '12/14/2015',
# ...
#  {'Unnamed: 0': 984,
#   'cycle': 2016,
#   'state': 'North Carolina',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 43.93365,
#   'pct_trend_adjusted': 44.14497,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 133,
#   'last_enddate': '3/20/2016',
#   '_medpoly2': 43.421974,
#   'trend_medpoly2': 43.394876,
#   '_shortpoly0': 44.035989,
#   'trend_shortpoly0': 44.294988,
#   'sum_weight_medium': 10.20679,
#   'sum_weight_short': 10.23283,
#   'sum_influence': 3.587327,
#   'sum_nat_influence': 2.465435,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 985,
#   'cycle': 2016,
#   'state': 'Ohio',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 45.99163,
#   'pct_trend_adjusted': 46.21128,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 121,
#   'last_enddate': '3/10/2016',
#   '_medpoly2': 47.016652,
#   'trend_medpoly2': 47.132574,
#   '_shortpoly0': 45.786623,
#   'trend_shortpoly0': 46.027028,
#   'sum_weight_medium': 7.266838,
#   'sum_weight_short': 7.266838,
#   'sum_influence': 5.251914,
#   'sum_nat_influence': 2.205327,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 986,
#   'cycle': 2016,
#   'state': 'Pennsylvania',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 45.41329,
#   'pct_trend_adjusted': 45.49741,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 131,
#   'last_enddate': '3/20/2016',
#   '_medpoly2': 46.335519,
#   'trend_medpoly2': 46.310385,
#   '_shortpoly0': 45.228846,
#   'trend_shortpoly0': 45.334814,
#   'sum_weight_medium': 3.146089,
#   'sum_weight_short': 3.146089,
#   'sum_influence': 2.188802,
#   'sum_nat_influence': 1.514679,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 987,
#   'cycle': 2016,
#   'state': 'South Carolina',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 42.0821,
#   'pct_trend_adjusted': 41.56334,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 6,
#   'last_enddate': '11/16/2015',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 42.0821,
#   'trend_shortpoly0': 41.563339,
#   'sum_weight_medium': 0.7809128,
#   'sum_weight_short': 0.7809128,
#   'sum_influence': 0.7809128,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 988,
#   'cycle': 2016,
#   'state': 'Texas',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 44.10943,
#   'pct_trend_adjusted': 44.56708,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 107,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 44.109428,
#   'trend_shortpoly0': 44.567078,
#   'sum_weight_medium': 1.799316,
#   'sum_weight_short': 1.799316,
#   'sum_influence': 1.799316,
#   'sum_nat_influence': 0.1097144,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 989,
#   'cycle': 2016,
#   'state': 'Utah',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 34.4317,
#   'pct_trend_adjusted': 34.17875,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 126,
#   'last_enddate': '3/15/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 34.431703,
#   'trend_shortpoly0': 34.178752,
#   'sum_weight_medium': 1.337078,
#   'sum_weight_short': 1.337078,
#   'sum_influence': 0.8546362,
#   'sum_nat_influence': 0.5309346,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 990,
#   'cycle': 2016,
#   'state': 'Virginia',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 49.96722,
#   'pct_trend_adjusted': 50.24106,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 105,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': 49.5066,
#   'trend_medpoly2': 50.153795,
#   '_shortpoly0': 50.059348,
#   'trend_shortpoly0': 50.258517,
#   'sum_weight_medium': 2.093773,
#   'sum_weight_short': 2.093773,
#   'sum_influence': 1.360229,
#   'sum_nat_influence': 0.038632,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 991,
#   'cycle': 2016,
#   'state': 'West Virginia',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 24.0,
#   'pct_trend_adjusted': 24.37728,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 107,
#   'last_enddate': '2/22/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 24.0,
#   'trend_shortpoly0': 24.377278,
#   'sum_weight_medium': 0.5626372,
#   'sum_weight_short': 0.5626372,
#   'sum_influence': 0.5626372,
#   'sum_nat_influence': 0.0343071,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 992,
#   'cycle': 2016,
#   'state': 'Wisconsin',
#   'modeldate': '3/20/2016',
#   'candidate_name': 'Hillary Rodham Clinton',
#   'candidate_id': 9207,
#   'pct_estimate': 48.39338,
#   'pct_trend_adjusted': 48.72039,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 105,
#   'last_enddate': '2/21/2016',
#   '_medpoly2': 48.303551,
#   'trend_medpoly2': 48.98738,
#   '_shortpoly0': 48.411341,
#   'trend_shortpoly0': 48.666991,
#   'sum_weight_medium': 3.306806,
#   'sum_weight_short': 3.306806,
#   'sum_influence': 2.057189,
#   'sum_nat_influence': 0.0569643,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 993,
#   'cycle': 2016,
#   'state': 'National',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Gary Johnson',
#   'candidate_id': 9459,
#   'pct_estimate': 10.16349,
#   'pct_trend_adjusted': 10.16349,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 133,
#   'last_enddate': '3/20/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 10.163492,
#   'trend_shortpoly0': 10.163492,
#   'sum_weight_medium': 1.373664,
#   'sum_weight_short': 1.373664,
#   'sum_influence': 1.373664,
#   'sum_nat_influence': 1.373664,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 994,
#   'cycle': 2016,
#   'state': 'Alabama',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 70.1137,
#   'pct_trend_adjusted': 68.45409,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 66,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 70.1137,
#   'trend_shortpoly0': 68.454094,
#   'sum_weight_medium': 1.293506,
#   'sum_weight_short': 1.293506,
#   'sum_influence': 1.293506,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 995,
#   'cycle': 2016,
#   'state': 'Alaska',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 51.63273,
#   'pct_trend_adjusted': 49.45393,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 63,
#   'last_enddate': '1/12/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 51.632729,
#   'trend_shortpoly0': 49.453926,
#   'sum_weight_medium': 0.8274046,
#   'sum_weight_short': 0.8274046,
#   'sum_influence': 0.8274046,
#   'sum_nat_influence': 0.0,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 996,
#   'cycle': 2016,
#   'state': 'Arizona',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 40.57235,
#   'pct_trend_adjusted': 39.06276,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 123,
#   'last_enddate': '3/11/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 40.572348,
#   'trend_shortpoly0': 39.062755,
#   'sum_weight_medium': 1.829361,
#   'sum_weight_short': 1.829361,
#   'sum_influence': 1.143855,
#   'sum_nat_influence': 0.5363843,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 997,
#   'cycle': 2016,
#   'state': 'Colorado',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 45.95323,
#   'pct_trend_adjusted': 43.13694,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 113,
#   'last_enddate': '2/29/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 45.953232,
#   'trend_shortpoly0': 43.136934,
#   'sum_weight_medium': 2.209496,
#   'sum_weight_short': 2.209496,
#   'sum_influence': 1.012831,
#   'sum_nat_influence': 0.0880834,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 998,
#   'cycle': 2016,
#   'state': 'Florida',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 43.40585,
#   'pct_trend_adjusted': 42.90337,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 129,
#   'last_enddate': '3/17/2016',
#   '_medpoly2': 40.416278,
#   'trend_medpoly2': 40.383371,
#   '_shortpoly0': 44.003769,
#   'trend_shortpoly0': 43.407376,
#   'sum_weight_medium': 10.85455,
#   'sum_weight_short': 10.85455,
#   'sum_influence': 4.637425,
#   'sum_nat_influence': 2.903138,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  {'Unnamed: 0': 999,
#   'cycle': 2016,
#   'state': 'Georgia',
#   'modeldate': '3/21/2016',
#   'candidate_name': 'Donald Trump',
#   'candidate_id': 9849,
#   'pct_estimate': 49.89524,
#   'pct_trend_adjusted': 49.36125,
#   'timestamp': '18:51:39 14 Jun 2020',
#   'comment': 'full archive 1968-2016',
#   'election_date': '11/8/2016',
#   'election_qdate': 448,
#   'last_qdate': 108,
#   'last_enddate': '2/23/2016',
#   '_medpoly2': nan,
#   'trend_medpoly2': nan,
#   '_shortpoly0': 49.895237,
#   'trend_shortpoly0': 49.361252,
#   'sum_weight_medium': 1.775305,
#   'sum_weight_short': 1.775305,
#   'sum_influence': 1.775305,
#   'sum_nat_influence': 0.1082503,
#   '_minpoints': 5,
#   '_defaultbasetime': 20,
#   '_numloops': 5,
#   '_state_houseeffects_weight': 0.5,
#   '_state_trendline_weight': 0.5,
#   '_out_of_state_house_discount': 0.02,
#   '_house_effects_multiplier': 1,
#   '_attenuate_endpoints': 'yes',
#   '_nonlinear_polynomial_degree': 2,
#   '_shortpoly_combpoly_weight': 0.8,
#   '_nat_shortpoly_combpoly_weight': 0.5},
#  ...]

# %% [markdown]
# ### Guessing the error message

# %% [markdown]
# * For each of the following errors, explain why it means, and why it is occurring.

# %%
records['state']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-fcc5683de51c> in <cell line: 1>()
# ----> 1 records['state']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Explain here
# We are trying to use a String as an index for a list, it needs to be an Int.

# %%
records.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8e35531cc972> in <cell line: 1>()
# ----> 1 records.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
# Explain here
# records object does not have keys() attribute/method to call

# %%
records[1_000_000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-9688ee58919f> in <cell line: 1>()
# ----> 1 records[1_000_000]
#
# IndexError: list index out of range

# %%
# What kind of error is this.  What do you think is occurring.
# we are trying to access something that does not exist. Our index does not exist in the list.

# %% [markdown]
# ### Discussion

# %% [markdown]
# Ok, so as we may have seen from the above, that our records are of type list.  The initial errors occurred because we were performing operations that are not available to a list.  And the last error occurred because we are selecting an element at index `1_000_000` where we do not have that many elements, thus getting the out of range error.

# %% [markdown]
# ### Continuing with Error Messages

# %% [markdown]
# Now without looking at the records, try to guess what is occurring with the error message below.

# %% [markdown]
# > Where specifically is the error occurring?

# %%
years = []
for record in records:
    years.append(int(record['cycle'].split()[-1]))
    # record['cycle'] is an Int, so it can not be split because split() is not a method on int type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-13a8d8e8ca59> in <cell line: 2>()
#       1 years = []
#       2 for record in records:
# ----> 3     years.append(int(record['cycle'].split()[-1]))
#
# AttributeError: 'int' object has no attribute 'split'

# %% [markdown]
# Then look at the data to better understand the error.
#
# Ok, now let's keep going with this.  What do you think is occurring in the error below.  What method or function is causing the error.
#
# > Use Google to search for this error message and understand when it typically occurs.

# %%
for record in records:
    int(record['modeldate'][:3])
    # the data we get back in String cannot be converted to an Int: "3/3"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d4e976c27696> in <cell line: 1>()
#       1 for record in records:
# ----> 2     int(record['modeldate'][:3])
#       3     # the data we get back in String cannot be converted to an Int: "3/3"
#
# ValueError: invalid literal for int() with base 10: '3/3'

# %% [markdown]
# ### Continued practice with debugging

# %% [markdown]
# Now this time, let's practice debugging trying to identify when our code is doing something different than we expected.

# %%
model_dates = []
for record in records:
    model_date = record.get('modeldate')
    candidate_name = record.get('candidate_name')
    candidate = {'model_date': model_date, 'candidate_name': candidate_name[:3]}

# %% [markdown]
# > Hint: Remember that when debugging, we can inspect what is occurring either by trying to perform the operations only on a single element.  Or we can also use the `print` function to view our data.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lesson, we spent some practice debugging.  The first step to debugging is to read and understand the error message.  If you do not understand the error message, it's a good idea to search Google to get a better understanding.
#
# Also take a look at each component of the error message, the carrot tells us where the error is occurring.  And the `type` of error tells us what kind of error we have.
#
# Then we saw a problem where the error occurred because our data is different than what we expected.  For this, it is a good idea to identify where our code is operating as we expected, and then find the place where things started to change.
